# %% [markdown]
# <a href="https://colab.research.google.com/github/NullSpac/aipython1/blob/main/240110%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame([['Kim', 27, 92],
                   ['Lee', 33, 98],
                   ['Park', 19, 87]])
df
# Out:
#       0   1   2
# 0   Kim  27  92
# 1   Lee  33  98
# 2  Park  19  87

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %%
df = pd.DataFrame({'name':['Kim', 'Lee', 'Park'],
                   'age':[15, 33, 98],
                   'score':[85, 65, 87]})
df
# Out:
#    name  age  score
# 0   Kim   15     85
# 1   Lee   33     65
# 2  Park   98     87

# %%
# df = pd.read_csv('data.csv')
# df

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv', delimiter='\t')
# df

# %%
# df = pd.read_csv('data.xlsx')
# df

# %%
df.head(3)
# Out:
#   name  age score
# 0  Kim  Lee  Park
# 1   27   33    19
# 2   92   98    87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      object
#  2   score   3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
df.loc[2]
# Out:
# name     92
# age      98
# score    87
# Name: 2, dtype: object

# %%
df.loc[0:2,['name']]
# Out:
#   name
# 0  Kim
# 1   27
# 2   92

# %%
df.iloc[1, 2]
# Out:
# 19

# %%
df.iloc[0:1, 0:1]
# Out:
#   name
# 0  Kim

# %%
df['age'] >= 15
# Out:
# 0    True
# 1    True
# 2    True
# Name: age, dtype: bool

# %%
df[df['age'] >= 15]
# Out:
#    name  age  score
# 0   Kim   15     85
# 1   Lee   33     65
# 2  Park   98     87

# %%
df[(df['age'] >= 15) & (df['score'] >= 75)]
# Out:
#    name  age  score
# 0   Kim   15     85
# 2  Park   98     87

# %%
df[(df['age'] >= 15) | (df['score'] >= 75)] # | : pipeline
# Out:
#    name  age  score
# 0   Kim   15     85
# 1   Lee   33     65
# 2  Park   98     87

# %%
df.sort_values(by='name', ascending=False)
# Out:
#    name  age  score
# 2  Park   98     87
# 1   Lee   33     65
# 0   Kim   15     85

# %%
df.describe()
# Out:
#              age      score
# count   3.000000   3.000000
# mean   48.666667  79.000000
# std    43.661577  12.165525
# min    15.000000  65.000000
# 25%    24.000000  75.000000
# 50%    33.000000  85.000000
# 75%    65.500000  86.000000
# max    98.000000  87.000000

# %%
df['age'].value_counts()
# Out:
# 15    1
# 33    1
# 98    1
# Name: age, dtype: int64

# %%
df.groupby('age').sum()
# Out:
# <ipython-input-39-0ee9020b3f6e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('age').sum()
#      score
# age
# 15      85
# 33      65
# 98      87

# %%
df['age + score'] = df['age'] + df['score']
df
# Out:
#    name  age  score  age + score
# 0   Kim   15     85          100
# 1   Lee   33     65           98
# 2  Park   98     87          185
